# %%
import sys
sys.path.append('./KPConv-PyTorch/')
from tester_celldata import test_model

# %%
chosen_log = "./checkpoints/"
test_model(chosen_log)
# Out:
# Data Preparation
# ****************
#
# Preparing KDTree for cloud t001, subsampled at 0.080
# 14.7 MB loaded in 3.4s
#
# Preparing KDTree for cloud t006, subsampled at 0.080
# 14.7 MB loaded in 3.4s
#
# Preparing KDTree for cloud t008, subsampled at 0.080
# 14.7 MB loaded in 4.0s
#
# Preparing KDTree for cloud t009, subsampled at 0.080
# 14.7 MB loaded in 5.4s
#
# Preparing KDTree for cloud t011, subsampled at 0.080
# 14.7 MB loaded in 4.5s
#
# Preparing KDTree for cloud t012, subsampled at 0.080
# 14.7 MB loaded in 4.1s
#
# Preparing KDTree for cloud t013, subsampled at 0.080
# 14.7 MB loaded in 4.2s
#
# Preparing KDTree for cloud t014, subsampled at 0.080
# 14.7 MB loaded in 4.4s
#
# Preparing KDTree for cloud t015, subsampled at 0.080
# 14.7 MB loaded in 4.4s
#
# Preparing KDTree for cloud t019, subsampled at 0.080
# 14.7 MB loaded in 4.7s
#
# Preparing KDTree for cloud t020, subsampled at 0.080
# 14.7 MB loaded in 4.3s
#
# Preparing KDTree for cloud t021, subsampled at 0.080
# 14.7 MB loaded in 4.2s
#
# Preparing KDTree for cloud t023, subsampled at 0.080
# 14.7 MB loaded in 4.2s
#
# Preparing KDTree for cloud t024, subsampled at 0.080
# 14.7 MB loaded in 4.1s
#
# Preparing KDTree for cloud t025, subsampled at 0.080
# 14.7 MB loaded in 4.0s
#
# Preparing potentials
# Done in 3.7s
#
# Preparing reprojection indices for testing
# t001 done in 0.0s
# t006 done in 0.1s
# t008 done in 0.1s
# t009 done in 0.1s
# t011 done in 0.1s
# t012 done in 0.1s
# t013 done in 0.1s
# t014 done in 0.1s
# t015 done in 0.1s
# t019 done in 0.1s
# t020 done in 0.1s
# t021 done in 0.1s
# t023 done in 0.1s
# t024 done in 0.2s
# t025 done in 0.1s
#
#
# Model Preparation
# *****************
# Model and training state restored.
# Done in 2.5s
#
#
# Start test
# **********
#
# Initialize workers
# Done in 0.0s
# e000-i0000 => 0.0% (timings : 8.98 2139.25 9.01)
# e000-i0011 => 5.5% (timings : 7.25 86.41 0.95)
# Test epoch 0, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e001-i0007 => 3.5% (timings : 7.77 89.45 0.84)
# Test epoch 1, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e002-i0003 => 1.5% (timings : 7.69 102.27 0.90)
# e002-i0014 => 7.0% (timings : 7.24 94.43 0.69)
# Test epoch 2, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e003-i0010 => 5.0% (timings : 7.22 89.35 0.46)
# Test epoch 3, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e004-i0006 => 3.0% (timings : 7.16 86.27 0.82)
# Test epoch 4, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e005-i0002 => 1.0% (timings : 6.98 83.58 1.00)
# e005-i0013 => 6.5% (timings : 6.76 87.48 0.96)
# Test epoch 5, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e006-i0009 => 4.5% (timings : 6.02 94.30 0.85)
# Test epoch 6, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e007-i0005 => 2.5% (timings : 6.86 93.78 1.00)
# Test epoch 7, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e008-i0001 => 0.5% (timings : 6.99 85.77 1.00)
# e008-i0012 => 6.0% (timings : 6.70 85.98 0.90)
# Test epoch 8, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e009-i0008 => 4.0% (timings : 7.14 84.86 0.73)
# Test epoch 9, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e010-i0004 => 2.0% (timings : 7.14 100.91 1.00)
# Test epoch 10, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e011-i0000 => 0.0% (timings : 9.97 89.30 1.00)
# e011-i0011 => 5.5% (timings : 7.58 88.93 0.75)
# Test epoch 11, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e012-i0007 => 3.5% (timings : 6.78 92.05 0.90)
# Test epoch 12, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e013-i0003 => 1.5% (timings : 6.36 90.76 1.81)
# e013-i0014 => 7.0% (timings : 6.87 90.89 1.06)
# Test epoch 13, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e014-i0009 => 4.5% (timings : 8.14 93.20 1.00)
# Test epoch 14, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e015-i0003 => 1.5% (timings : 8.87 106.14 0.98)
# e015-i0012 => 6.0% (timings : 8.94 112.48 1.00)
# Test epoch 15, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e016-i0006 => 3.0% (timings : 8.39 106.74 0.82)
# Test epoch 16, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e017-i0000 => 0.0% (timings : 9.97 104.72 1.00)
# e017-i0009 => 4.5% (timings : 9.94 106.43 1.00)
# Test epoch 17, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e018-i0003 => 1.5% (timings : 6.17 103.24 1.30)
# e018-i0012 => 6.0% (timings : 8.45 109.82 1.01)
# Test epoch 18, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e019-i0005 => 2.5% (timings : 9.19 135.63 1.29)
# e019-i0012 => 6.0% (timings : 10.61 144.13 1.43)
# Test epoch 19, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e020-i0003 => 1.5% (timings : 11.13 172.04 1.79)
# e020-i0009 => 4.5% (timings : 12.04 170.74 1.64)
# Test epoch 20, end. Min potential = 0.0
# Initialize workers
# Done in 0.0s
# e021-i0000 => 0.0% (timings : 15.96 164.09 1.00)
