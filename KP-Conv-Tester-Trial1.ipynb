# %%
import sys
sys.path.append('./KPConv-PyTorch/')
from tester_celldata import test_model

# %%
chosen_log = "results/Log_2020-07-16_10-30-51"
test_model(chosen_log)
# Out:
# results/Log_2020-07-16_10-30-51
#
# Data Preparation
# ****************
#
# Preparing KDTree for cloud t001, subsampled at 0.080
# Shape of the loaded point cloud = (157519, 5)
# 4.4 MB loaded in 1.4s
#
# Preparing potentials
# Done in 0.0s
#
# Preparing reprojection indices for testing
# t001 done in 0.0s
#
#
# Model Preparation
# *****************
# Model and training state restored.
# Done in 1.9s
#
#
# Start Prediction
# **********
#
# Initialize workers
# Done in 0.0s
# e000-i0000 => 0.0% (timings : 5.99 1059.13 0.00)
# e000-i0013 => 6.5% (timings : 6.56 74.50 0.38)
# e000-i0026 => 13.0% (timings : 6.20 74.46 0.61)
# e000-i0039 => 19.5% (timings : 6.42 72.65 0.59)
# e000-i0052 => 26.0% (timings : 6.26 71.54 0.60)
# e000-i0065 => 32.5% (timings : 6.04 74.08 0.71)
# e000-i0078 => 39.0% (timings : 6.20 71.81 0.77)
# e000-i0091 => 45.5% (timings : 6.27 70.35 0.52)
# e000-i0105 => 52.5% (timings : 6.31 68.88 0.66)
# e000-i0117 => 58.5% (timings : 6.27 73.36 0.70)
# ...
